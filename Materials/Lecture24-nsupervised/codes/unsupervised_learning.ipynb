# %% [markdown]
# # Mounting Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Class/AIChemistry/HandsOn15-Unsupervised
# Out:
# /content/drive/MyDrive/Class/AIChemistry/HandsOn15-Unsupervised

# %% [markdown]
# #Digits Example
# ## load data

# %%
from sklearn import manifold, datasets, decomposition, discriminant_analysis
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
import matplotlib.pyplot as plt
datum = X[1500,:]
datum = datum.reshape(8,8)
plt.imshow(datum)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
Z = pca.fit_transform(X)
print(X.shape)
print(Z.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
import matplotlib
fig = plt.figure(figsize=(15,15))
plt.scatter(Z[:,0],Z[:,1],s=50, c=y, cmap='tab10')
cb = plt.colorbar()

# %%
from sklearn.cluster import KMeans
cluster = KMeans(n_clusters=10)
labels = cluster.fit_predict(Z)

# %%
import matplotlib
fig = plt.figure(figsize=(15,15))
plt.scatter(Z[:,0],Z[:,1],s=50, c=labels, cmap='tab10')
cb = plt.colorbar()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
Z = tsne.fit_transform(X)
print(X.shape)
print(Z.shape)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (1797, 64)
# (1797, 2)

# %%
import matplotlib
fig = plt.figure(figsize=(15,15))
plt.scatter(Z[:,0],Z[:,1],s=50, c=y, cmap='tab10')
cb = plt.colorbar()

# %%
from sklearn.cluster import KMeans
cluster = KMeans(n_clusters=10)
labels = cluster.fit_predict(Z)
fig = plt.figure(figsize=(15,15))
plt.scatter(Z[:,0],Z[:,1],s=50, c=labels, cmap='tab10')
cb = plt.colorbar()

# %% [markdown]
# #Load Data

# %%
import numpy as np
import csv
data = []
with open('data.csv') as f:
  reader = csv.reader(f)
  next(reader)
  for row in reader:
    data.append([float(s) for s in row[1:]])
data =  np.array(data)

# %% [markdown]
# # PCA

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
z = pca.fit_transform(data)
print(pca.explained_variance_ratio_)
# Out:
# [0.19789801 0.0538968 ]

# %%
plt.scatter(z[:,0],z[:,1])

# %%
elements = ['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds', 'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og']
for s,i in zip(elements,pca.components_[0,:]):
  print('%-2s'%s,'% .2f'%i)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
Z = tsne.fit_transform(data)
print(X.shape)
print(Z.shape)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (1797, 64)
# (41599, 2)

# %%
import matplotlib
c = data[:,77]>0
fig = plt.figure(figsize=(15,15))
plt.scatter(Z[:,0],Z[:,1],c=c,s=50)

# %%
print(['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds', 'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og'].index('Pt'))
# Out:
# 77
